# %%
# pip install earthaccess geopandas shapely rioxarray xarray matplotlib
from pathlib import Path
import warnings
import earthaccess as ea
import geopandas as gpd
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import box
from shapely import wkt as swkt

# ── Config ───────────────────────────────────────────────────────────────────
OKAV_BBOX = (21.0, -21.5, 24.8, -17.5)   # (minLon, minLat, maxLon, maxLat)
START, END  = "2024-01-01", "2025-12-31"
OUT = Path("swot_okavango_wetland"); OUT.mkdir(exist_ok=True)
MAX_PER_PRODUCT = 3   # grab a few passes to see seasonal variation

# For Okavango *wetland* / floodplain, the relevant products are:
#   SWOT_L2_HR_Raster_2.0  – 100 m gridded water_frac / WSE  ← PRIMARY
#   SWOT_L2_HR_LakeSP_2.0  – waterbody polygons (large wetland pools)
#
# Excluded: RiverSP (river channels only), PIXC/PIXCVec (very large, channel-centric)
PRODUCTS = [
    "SWOT_L2_HR_Raster_2.0",
    "SWOT_L2_HR_LakeSP_2.0",
]

ea.login()

# ── Helpers ───────────────────────────────────────────────────────────────────
# Study-area bounding box as a GeoDataFrame (used for clipping/overlay)
B = gpd.GeoDataFrame(geometry=[box(*OKAV_BBOX)], crs="EPSG:4326")


def fetch_sample(short_name, outdir: Path = OUT, n: int = MAX_PER_PRODUCT):
    """Search and download up to n granules for a SWOT product within bbox/time."""
    res = ea.search_data(short_name=short_name,
                         temporal=(START, END),
                         bounding_box=OKAV_BBOX)
    if not res:
        print(f"[{short_name}] no granules found")
        return []
    res = res[:n]
    tgt = outdir / short_name
    tgt.mkdir(parents=True, exist_ok=True)
    print(f"[{short_name}] downloading {len(res)} granule(s) → {tgt}")
    ea.download(res, tgt.as_posix())
    return sorted(p for p in tgt.rglob("*") if p.is_file())


# ── Raster: water_frac (wetland inundation fraction) ─────────────────────────
def plot_raster_wetland(files, title_prefix="SWOT Raster"):
    """
    Plot water_frac from SWOT L2 HR Raster NetCDF files.
    water_frac ∈ [0, 1]: fraction of each ~100 m pixel covered by water.
    This is the primary variable for wetland / floodplain inundation mapping.
    WSE (water surface elevation) is plotted as a secondary if water_frac absent.
    """
    nc_files = [f for f in files if f.suffix.lower() == ".nc"]
    if not nc_files:
        print("[Raster] no .nc files found")
        return

    for f in nc_files:
        try:
            ds = xr.open_dataset(f, mask_and_scale=True)
        except Exception as e:
            print(f"[Raster] could not open {f.name}: {e}"); continue

        # Choose variable – water_frac best for wetland inundation extent
        for vname in ("water_frac", "water_area_total", "wse", "sig0"):
            if vname in ds.data_vars:
                break
        else:
            vname = list(ds.data_vars)[0]

        da = ds[vname].squeeze()

        # Identify lat/lon dimension names (Raster uses 'latitude'/'longitude' or 'y'/'x')
        lat_dim = next((d for d in da.dims if "lat" in d.lower() or d == "y"), None)
        lon_dim = next((d for d in da.dims if "lon" in d.lower() or d == "x"), None)
        if lat_dim is None or lon_dim is None:
            print(f"[Raster] {f.name}: cannot identify lat/lon dims in {list(da.dims)}"); ds.close(); continue

        minx, miny, maxx, maxy = OKAV_BBOX
        # Clip — lat may be ascending or descending
        try:
            da_clip = da.sel({lon_dim: slice(minx, maxx), lat_dim: slice(miny, maxy)})
            if da_clip.size == 0:
                da_clip = da.sel({lon_dim: slice(minx, maxx), lat_dim: slice(maxy, miny)})
        except Exception:
            da_clip = da

        vals = da_clip.values.astype(float)
        vals = np.where((vals < -1e10) | (vals > 1e15), np.nan, vals)

        if np.all(np.isnan(vals)):
            print(f"[Raster] {f.name}: all NaN after clipping – pass may not overlap bbox"); ds.close(); continue

        lat_vals = da_clip[lat_dim].values
        lon_vals = da_clip[lon_dim].values

        cmap  = "Blues"  if vname == "water_frac" else "viridis"
        vmin  = 0;  vmax = 1  if vname == "water_frac" else None
        if vmax is None:
            p2, p98 = np.nanpercentile(vals, 2), np.nanpercentile(vals, 98)
            vmin, vmax = p2, p98

        date_str = str(ds.attrs.get("time_coverage_start", f.stem))[:10]
        units    = ds[vname].attrs.get("units", "")

        fig, ax = plt.subplots(figsize=(8, 6))
        pm = ax.pcolormesh(lon_vals, lat_vals, vals,
                           cmap=cmap, vmin=vmin, vmax=vmax, shading="auto")
        plt.colorbar(pm, ax=ax, label=f"{vname}" + (f" ({units})" if units else ""))
        B.boundary.plot(ax=ax, edgecolor="red", linewidth=1.2, label="Study area")
        ax.set_title(f"{title_prefix} — {vname} — {date_str}")
        ax.set_xlabel("Lon"); ax.set_ylabel("Lat")
        ax.legend(); fig.tight_layout(); plt.show()
        ds.close()


# ── LakeSP: wetland waterbody polygons ───────────────────────────────────────
def read_lakesp_nc(f: Path) -> gpd.GeoDataFrame | None:
    """
    SWOT LakeSP files are NetCDF-4 with geometry stored as WKT byte strings
    in a 'geometry' variable — NOT shapefiles.
    """
    try:
        ds = xr.open_dataset(f, mask_and_scale=False)
    except Exception as e:
        print(f"[LakeSP] cannot open {f.name}: {e}"); return None

    if "geometry" not in ds.variables:
        print(f"[LakeSP] no 'geometry' variable in {f.name} — vars: {list(ds.data_vars)}")
        ds.close(); return None

    raw = ds["geometry"].values
    geoms = []
    for g in raw:
        try:
            s = g.decode("utf-8") if isinstance(g, (bytes, bytearray)) else str(g)
            geoms.append(swkt.loads(s))
        except Exception:
            geoms.append(None)

    # Build attribute table from 1-D variables matching the feature count
    n = len(geoms)
    attr = {}
    for v in ds.data_vars:
        if v == "geometry": continue
        arr = ds[v].values
        if arr.shape == (n,):
            attr[v] = arr

    gdf = gpd.GeoDataFrame(attr, geometry=geoms, crs="EPSG:4326")
    gdf = gdf[gdf.geometry.notna()]
    ds.close()
    return gdf


def plot_lakesp_wetland(files, title="SWOT LakeSP — Okavango wetland"):
    nc_files = [f for f in files if f.suffix.lower() == ".nc"]
    if not nc_files:
        print("[LakeSP] no .nc files found"); return

    for f in nc_files:
        gdf = read_lakesp_nc(f)
        if gdf is None or gdf.empty:
            print(f"[LakeSP] empty result: {f.name}"); continue

        clipped = gdf.clip(B.unary_union)
        if clipped.empty:
            print(f"[LakeSP] no features intersect bbox: {f.name}"); continue

        # Colour by water surface elevation if available, else solid fill
        wse_col = next((c for c in clipped.columns if "wse" in c.lower()), None)
        date_str = f.stem[:10] if len(f.stem) >= 10 else f.stem

        fig, ax = plt.subplots(figsize=(8, 6))
        B.boundary.plot(ax=ax, edgecolor="red", linewidth=1.2, label="Study area")
        if wse_col:
            clipped.plot(ax=ax, column=wse_col, cmap="Blues",
                         legend=True, legend_kwds={"label": "WSE (m)"}, alpha=0.7)
        else:
            clipped.plot(ax=ax, facecolor="steelblue", edgecolor="navy",
                         alpha=0.6, linewidth=0.5)
        ax.set_title(f"{title} — {date_str}")
        ax.set_xlabel("Lon"); ax.set_ylabel("Lat")
        fig.tight_layout(); plt.show()


# ── Run ───────────────────────────────────────────────────────────────────────
all_files = {prod: fetch_sample(prod) for prod in PRODUCTS}

print("\n=== SWOT Raster: water fraction (wetland inundation extent) ===")
plot_raster_wetland(all_files["SWOT_L2_HR_Raster_2.0"])

print("\n=== SWOT LakeSP: waterbody polygons ===")
plot_lakesp_wetland(all_files["SWOT_L2_HR_LakeSP_2.0"])
# Out:
# [SWOT_L2_HR_Raster_2.0] downloading 3 granule(s) → swot_okavango_wetland/SWOT_L2_HR_Raster_2.0
# QUEUEING TASKS | :   0%|          | 0/3 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/3 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/3 [00:00<?, ?it/s]
# [SWOT_L2_HR_LakeSP_2.0] downloading 3 granule(s) → swot_okavango_wetland/SWOT_L2_HR_LakeSP_2.0
# QUEUEING TASKS | :   0%|          | 0/3 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/3 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/3 [00:00<?, ?it/s]
# === SWOT Raster: water fraction (wetland inundation extent) ===
# [Raster] SWOT_L2_HR_Raster_100m_UTM34K_N_x_x_x_008_514_093F_20240101T151223_20240101T151244_PIC0_01.nc: all NaN after clipping – pass may not overlap bbox
# [Raster] SWOT_L2_HR_Raster_250m_UTM34K_N_x_x_x_008_514_093F_20240101T151223_20240101T151244_PGC0_02.nc: all NaN after clipping – pass may not overlap bbox
# ...

# %% [markdown]
# Last edited: 2026-03-11
